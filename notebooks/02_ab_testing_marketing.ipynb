# %% [markdown]
# # 02 — A/B Testing: Marketing campaign conversion
#
# **Question:** does seeing the ad (vs. a public service announcement) increase conversion rate?
#
# **Technique focus:** conversion-rate test, CUPED variance reduction using a pre-experiment covariate, multiple-comparisons correction if you slice by day/hour.
#
# **Data:** Kaggle `marketing-ab-testing`. Download per README, place in `data/raw/marketing_AB.csv`.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

# %%
df = pd.read_csv(DATA_RAW / "marketing_AB.csv")
df.head()

# %% [markdown]
# ## TODO
# 1. Compute overall conversion rate for `ad` vs `psa` groups and test the difference.
# 2. The dataset has `total ads` and `most ads day/hour` per user — try CUPED using `total ads` (or another pre-treatment-like covariate) to reduce variance, and compare the CI width before/after.
# 3. Slice the effect by day-of-week or hour. If you run many slices, apply a multiple-comparisons correction (Bonferroni or FDR) before claiming any slice is significant.
# 4. Write a 3-sentence recommendation as if reporting to a stakeholder.
