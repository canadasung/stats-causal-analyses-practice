# %% [markdown]
# # 04 — Matching & IPW: Lalonde job training data
#
# **Question:** what was the effect of the NSW job training program on 1978 earnings?
#
# **Why this dataset:** the NSW program was originally a randomized experiment, but the commonly distributed Lalonde dataset replaces the randomized control group with a non-experimental comparison group (from CPS/PSID), so you can check whether your observational method recovers something close to the experimental benchmark (~$1,794, per Lalonde 1986 / Dehejia & Wahba 1999).
#
# **Technique focus:** propensity score estimation, matching, inverse probability weighting (IPW), covariate balance checks.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

from causaldata import lalonde

# %%
df = lalonde.load_pandas().data
df.head()

# %% [markdown]
# ## TODO
# 1. Compare the naive (unadjusted) difference in 1978 earnings between treated and control to the experimental benchmark — how far off is it, and why?
# 2. Fit a propensity score model (logistic regression) for treatment using pre-treatment covariates (age, education, race, married, nodegree, 1974/1975 earnings).
# 3. Check covariate balance before/after weighting or matching (standardized mean differences, or just compare means by group).
# 4. Estimate the treatment effect via IPW and via nearest-neighbor matching on the propensity score. Compare the two estimates and their CIs.
# 5. Compare your observational estimate to the experimental benchmark. Discuss what this tells you about unobserved confounding in this setting.
