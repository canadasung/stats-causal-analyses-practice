# %% [markdown]
# # 03 — A/B Testing: simulation and power analysis
#
# **Goal:** generate your own A/B data with a *known* true effect, then check whether your testing procedure recovers it — the only way to validate a method when you don't have ground truth on real data.
#
# **Technique focus:** power analysis / minimum detectable effect, Type I/II error rates via simulation, sequential testing (peeking problem).

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

# %% [markdown]
# ## TODO
# 1. Pick a baseline conversion rate (e.g. 5%) and a true lift (e.g. +1pp). Simulate 1000 experiments at a chosen sample size and record how often the test correctly rejects the null at alpha=0.05 (this is your empirical power).
# 2. Repeat with true lift = 0 to confirm your false-positive rate matches alpha.
# 3. Use `statsmodels.stats.power` to compute the required sample size for 80% power given your baseline rate and minimum detectable effect, and check it against your simulation.
# 4. Simulate the 'peeking' problem: run a z-test after every 50 new observations and stop as soon as p < 0.05. Compare the resulting false-positive rate to the nominal alpha under continuous monitoring with no correction.
# 5. Fix the peeking problem with a simple approach (e.g. a fixed pre-registered sample size, or a sequential testing correction) and re-run.
