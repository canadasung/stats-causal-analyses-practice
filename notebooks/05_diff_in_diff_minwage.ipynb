# %% [markdown]
# # 05 — Difference-in-Differences: Card & Krueger minimum wage
#
# **Question:** did raising New Jersey's minimum wage in 1992 reduce fast-food employment, relative to Pennsylvania (no wage change)?
#
# **Technique focus:** 2x2 difference-in-differences, the parallel-trends assumption, DiD via regression with an interaction term.
#
# **Data:** `causaldata.minwage` (Card & Krueger 1994 replication data).

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

from causaldata import minwage
import statsmodels.formula.api as smf

# %%
df = minwage.load_pandas().data
df.head()

# %% [markdown]
# ## TODO
# 1. Identify the treatment group (NJ) and control group (PA), and the pre/post periods in this data (check the column documentation/codebook for `minwage`).
# 2. Compute the simple 2x2 DiD by hand: mean employment change in NJ minus mean employment change in PA.
# 3. Replicate the same estimate via OLS with `employment ~ treated + post + treated:post`, where the interaction coefficient is your DiD estimate. Confirm it matches step 2.
# 4. Discuss the parallel-trends assumption: what would have to be true for this estimate to be causal? Is there any way to probe it with this data (e.g. pre-period trends if multiple pre-periods exist)?
# 5. Compare your result to the original Card & Krueger finding (employment did not fall in NJ relative to PA) — does your estimate agree?
