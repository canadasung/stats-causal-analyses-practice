# %% [markdown]
# # 06 — Instrumental Variables: Card's college proximity
#
# **Question:** what is the causal effect of education on wages, given that education is confounded by unobserved ability?
#
# **Instrument:** growing up near a 4-year college (`nearc4`) — assumed to affect education (access) but not wages directly except through education.
#
# **Technique focus:** two-stage least squares (2SLS), instrument relevance (first-stage F-stat) and the exclusion restriction as an assumption you can't test directly.
#
# **Data:** `causaldata.card`.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

from causaldata import card
from linearmodels.iv import IV2SLS
import statsmodels.formula.api as smf

# %%
df = card.load_pandas().data
df.head()

# %% [markdown]
# ## TODO
# 1. Run the naive OLS regression of log wage on education (plus controls like experience, race, region). This is biased if ability confounds both.
# 2. Run the first stage: regress education on `nearc4` plus the same controls. Check the F-statistic on the instrument — is it weak (rule of thumb: F > 10)?
# 3. Run 2SLS (`linearmodels.iv.IV2SLS`) with `nearc4` instrumenting for education. Compare the IV estimate to the OLS estimate — which direction does it move, and does that match what you'd expect if ability bias is positive?
# 4. Discuss the exclusion restriction: what's a plausible way `nearc4` could affect wages *other than* through education? How would that bias your estimate?
