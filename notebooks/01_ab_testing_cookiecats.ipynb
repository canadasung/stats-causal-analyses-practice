# %% [markdown]
# # 01 — A/B Testing: Cookie Cats retention
#
# **Question:** does moving a game's progression gate from level 30 to level 40 change 1-day / 7-day retention?
#
# **Technique focus:** two-proportion z-test, confidence intervals on a difference in proportions, sample ratio mismatch (SRM) check.
#
# **Data:** Kaggle `mobile-games-ab-testing` (Cookie Cats). Download per README, place in `data/raw/cookie_cats.csv`.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path.cwd().parent / "src"))
from utils import DATA_RAW, DATA_PROCESSED, set_plot_style

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

set_plot_style()

# %%
df = pd.read_csv(DATA_RAW / "cookie_cats.csv")
df.head()

# %% [markdown]
# ## TODO
# 1. Check sample ratio mismatch between `gate_30` and `gate_40` groups — are they close to 50/50? If not, that's a red flag before trusting the test.
# 2. Compute 1-day and 7-day retention rate per group.
# 3. Run a two-proportion z-test (or chi-squared test) for each retention metric. State the null/alternative hypotheses explicitly first.
# 4. Compute a confidence interval for the difference in retention rates.
# 5. Interpret: is the effect statistically *and* practically significant? What would you tell the product team?
